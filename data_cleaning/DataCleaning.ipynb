# %%
# !pip install pandas
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Skipping /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests-2.31.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas-2.0.3.dist-info due to invalid metadata entry 'name'
# ...
#   Using cached pandas-2.1.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 3.4 MB/s eta 0:00:00
# ...
# Using cached pandas-2.1.3-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 16.3 MB/s eta 0:00:00a 0:00:01
# WARNING: Skipping /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests-2.31.0.dist-info due to invalid metadata entry 'name'
# ...

# %%
amazon_path = "/Users/COMPUTER/PycharmProjects/pythonProject2/datasets/amazon_products.csv"
amazon = pd.read_csv(amazon_path)
amazon.head()
# Out:
#          asin                                              title  \
# 0  B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1  B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2  B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3  B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4  B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/815dLQKYIY...
# 1  https://m.media-amazon.com/images/I/81bQlm7vf6...
# 2  https://m.media-amazon.com/images/I/71EA35zvJB...
# 3  https://m.media-amazon.com/images/I/91k6NYLQyI...
# 4  https://m.media-amazon.com/images/I/61NJoaZcP9...
#
#                              productURL  stars  reviews   price  listPrice  \
# 0  https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99       0.00
# 1  https://www.amazon.com/dp/B07GDLCQXV    4.5        0  169.99     209.99
# ...

# %%
amazon['asin'].is_unique
# Out:
# True

# %%
amazon['title'].is_unique
# Out:
# False

# %%
amazon = amazon.set_index('asin')

# %%
amazon.head()
# Out:
#                                                         title  \
# asin
# B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
#
#                                                        imgUrl  \
# asin
# B014TMV5YE  https://m.media-amazon.com/images/I/815dLQKYIY...
# B07GDLCQXV  https://m.media-amazon.com/images/I/81bQlm7vf6...
# B07XSCCZYG  https://m.media-amazon.com/images/I/71EA35zvJB...
# B08MVFKGJM  https://m.media-amazon.com/images/I/91k6NYLQyI...
# B01DJLKZBA  https://m.media-amazon.com/images/I/61NJoaZcP9...
#
#                                       productURL  stars  reviews   price  \
# asin
# B014TMV5YE  https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99
# ...

# %%
#Convert True/False to 0/1
amazon['isBestSeller'] = amazon['isBestSeller'].astype(int)

# %%
amazon.head()
# Out:
#                                                         title  \
# asin
# B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
#
#                                                        imgUrl  \
# asin
# B014TMV5YE  https://m.media-amazon.com/images/I/815dLQKYIY...
# B07GDLCQXV  https://m.media-amazon.com/images/I/81bQlm7vf6...
# B07XSCCZYG  https://m.media-amazon.com/images/I/71EA35zvJB...
# B08MVFKGJM  https://m.media-amazon.com/images/I/91k6NYLQyI...
# B01DJLKZBA  https://m.media-amazon.com/images/I/61NJoaZcP9...
#
#                                       productURL  stars  reviews   price  \
# asin
# B014TMV5YE  https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99
# ...

# %%
# Remove rows with null or 0.00 price and products with null titles
amazon = amazon[amazon['price'].notnull() & (amazon['price'] != 0.00) & (amazon['title'].notnull())]

# %%
amazon.head()
# Out:
#                                                         title  \
# asin
# B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
#
#                                                        imgUrl  \
# asin
# B014TMV5YE  https://m.media-amazon.com/images/I/815dLQKYIY...
# B07GDLCQXV  https://m.media-amazon.com/images/I/81bQlm7vf6...
# B07XSCCZYG  https://m.media-amazon.com/images/I/71EA35zvJB...
# B08MVFKGJM  https://m.media-amazon.com/images/I/91k6NYLQyI...
# B01DJLKZBA  https://m.media-amazon.com/images/I/61NJoaZcP9...
#
#                                       productURL  stars  reviews   price  \
# asin
# B014TMV5YE  https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99
# ...

# %%
amazon.head(1000)
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Uniq Id          30000 non-null  object
#  1   Crawl Timestamp  30000 non-null  object
#  2   Product Url      30000 non-null  object
#  3   Product Name     30000 non-null  object
#  4   Description      30000 non-null  object
#  5   List Price       30000 non-null  float64
#  6   Sale Price       30000 non-null  float64
#  7   Brand            29481 non-null  object
#  8   Item Number      8554 non-null   float64
#  9   Gtin             30000 non-null  int64
#  10  Package Size     0 non-null      float64
#  11  Category         29976 non-null  object
#  12  Postal Code      0 non-null      float64
#  13  Available        30000 non-null  bool
# dtypes: bool(1), float64(5), int64(1), object(7)
# memory usage: 3.0+ MB

# %%
amazon.to_csv('amazon_cleaned_data.csv', index=True)

# %%
walmart_path = "/Users/COMPUTER/PycharmProjects/pythonProject2/datasets/marketing_sample_for_walmart_com-product_details__20200101_20200331__30k_data.csv"
walmart = pd.read_csv(walmart_path)
walmart.head()
# Out:
#                             Uniq Id            Crawl Timestamp  \
# 0  51b010b871cde349bd32159a1cc1a15f  2020-01-24 16:08:36 +0000
# 1  d6a7f100e44a626a3701804e99236ad6  2020-01-24 15:54:21 +0000
# 2  99d2b7da7e3e427a942f864937dacd9d  2020-01-24 18:34:28 +0000
# 3  4c76d170c2c6a759cbce812d790a0b88  2020-01-24 11:08:53 +0000
# 4  8ac95837dc8baa01e504fd8f633ffaf2  2020-03-10 07:37:21 +0000
#
#                                          Product Url  \
# 0  https://www.walmart.com/ip/Allegiance-Economy-...
# 1  https://www.walmart.com/ip/Kenneth-Cole-Reacti...
# 2  https://www.walmart.com/ip/Kid-Tough-Fitness-I...
# 3  https://www.walmart.com/ip/THE-FIRST-YEARS/167...
# 4  https://www.walmart.com/ip/4-Pack-MD-USA-Seaml...
#
#                                         Product Name  \
# 0  Allegiance Economy Dual-scale Digital Thermometer
# 1  Kenneth Cole Reaction Eau De Parfum Spray For ...
# 2  Kid Tough Fitness Inflatable Free-Standing Pun...
# ...

# %%
walmart['Uniq Id'].is_unique
# Out:
# True

# %%
walmart = walmart.set_index('Uniq Id')

# %%
walmart.head()
# Out:
#                                             Crawl Timestamp  \
# Uniq Id
# 51b010b871cde349bd32159a1cc1a15f  2020-01-24 16:08:36 +0000
# d6a7f100e44a626a3701804e99236ad6  2020-01-24 15:54:21 +0000
# 99d2b7da7e3e427a942f864937dacd9d  2020-01-24 18:34:28 +0000
# 4c76d170c2c6a759cbce812d790a0b88  2020-01-24 11:08:53 +0000
# 8ac95837dc8baa01e504fd8f633ffaf2  2020-03-10 07:37:21 +0000
#
#                                                                         Product Url  \
# Uniq Id
# 51b010b871cde349bd32159a1cc1a15f  https://www.walmart.com/ip/Allegiance-Economy-...
# d6a7f100e44a626a3701804e99236ad6  https://www.walmart.com/ip/Kenneth-Cole-Reacti...
# 99d2b7da7e3e427a942f864937dacd9d  https://www.walmart.com/ip/Kid-Tough-Fitness-I...
# 4c76d170c2c6a759cbce812d790a0b88  https://www.walmart.com/ip/THE-FIRST-YEARS/167...
# 8ac95837dc8baa01e504fd8f633ffaf2  https://www.walmart.com/ip/4-Pack-MD-USA-Seaml...
#
# ...

# %%
walmart = walmart.drop(['Item Number', 'Gtin', 'Package Size', 'Postal Code', 'Crawl Timestamp'], axis=1)
walmart.head()
# Out:
#                                                                         Product Url  \
# Uniq Id
# 51b010b871cde349bd32159a1cc1a15f  https://www.walmart.com/ip/Allegiance-Economy-...
# d6a7f100e44a626a3701804e99236ad6  https://www.walmart.com/ip/Kenneth-Cole-Reacti...
# 99d2b7da7e3e427a942f864937dacd9d  https://www.walmart.com/ip/Kid-Tough-Fitness-I...
# 4c76d170c2c6a759cbce812d790a0b88  https://www.walmart.com/ip/THE-FIRST-YEARS/167...
# 8ac95837dc8baa01e504fd8f633ffaf2  https://www.walmart.com/ip/4-Pack-MD-USA-Seaml...
#
#                                                                        Product Name  \
# Uniq Id
# 51b010b871cde349bd32159a1cc1a15f  Allegiance Economy Dual-scale Digital Thermometer
# d6a7f100e44a626a3701804e99236ad6  Kenneth Cole Reaction Eau De Parfum Spray For ...
# 99d2b7da7e3e427a942f864937dacd9d  Kid Tough Fitness Inflatable Free-Standing Pun...
# 4c76d170c2c6a759cbce812d790a0b88                                    THE FIRST YEARS
# ...

# %%
# Remove rows with null or 0.00 price and products with null titles
walmart = walmart[walmart['Sale Price'].notnull() & (walmart['Sale Price'] != 0.00) & (walmart['Product Name'].notnull())]
#Convert True/False to 0/1
walmart['Available'] = walmart['Available'].astype(int)
walmart.head(50)
walmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29659 entries, 51b010b871cde349bd32159a1cc1a15f to 062b706e1c308379bfe5a5bdc876a514
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Url   29659 non-null  object
#  1   Product Name  29659 non-null  object
#  2   Description   29659 non-null  object
#  3   List Price    29659 non-null  float64
#  4   Sale Price    29659 non-null  float64
#  5   Brand         29144 non-null  object
#  6   Category      29635 non-null  object
#  7   Available     29659 non-null  int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 2.0+ MB

# %%
walmart.to_csv('cleaned_data/walmart_cleaned_data.csv', index=True)

# %%
shein_path = "/Users/COMPUTER/PycharmProjects/pythonProject2/datasets/shein_sample.csv"
shein = pd.read_csv(shein_path, sep=';', encoding='ISO-8859-1')
shein.head()
# Out:
#                                                  url  \
# 0  https://us.shein.com/Flower-Decor-Face-Coverin...
# 1  https://us.shein.com/Lace-Up-Bodycon-Skirt-p-7...
# 2  https://us.shein.com/High-Waist-Twist-Front-Sh...
# 3  https://us.shein.com/ROMWE-Sweetness-Cherry-La...
# 4  https://us.shein.com/Cut-Out-Criss-Cross-One-P...
#
#                                      name                       sku  price  \
# 0        Flower Decor Face Covering Chain   SKU: sc2302055742295937  $2.50
# 1                   Lace Up Bodycon Skirt   SKU: sw2111151588254852  $7.25
# 2           High Waist Twist Front Shorts   SKU: sw2211215551435599  $8.99
# 3    ROMWE Sweetness Cherry Lace Cami Top   SKU: rw2203161166248409  $7.00
# 4  Cut Out Criss Cross One Piece Swimsuit   SKU: sw2108269195581516  $9.50
#
#                                      size  \
# 0                                one-size
# 1                 XS(2),S(4),M(6),L(8/10)
# 2                S(4),M(6),L(8/10),XL(12)
# ...

# %%
shein['sku'].is_unique
# Out:
# False

# %%
shein = shein.drop(['sku','size'], axis=1)
shein.head()
# Out:
#                                                  url  \
# 0  https://us.shein.com/Flower-Decor-Face-Coverin...
# 1  https://us.shein.com/Lace-Up-Bodycon-Skirt-p-7...
# 2  https://us.shein.com/High-Waist-Twist-Front-Sh...
# 3  https://us.shein.com/ROMWE-Sweetness-Cherry-La...
# 4  https://us.shein.com/Cut-Out-Criss-Cross-One-P...
#
#                                      name  price  \
# 0        Flower Decor Face Covering Chain  $2.50
# 1                   Lace Up Bodycon Skirt  $7.25
# 2           High Waist Twist Front Shorts  $8.99
# 3    ROMWE Sweetness Cherry Lace Cami Top  $7.00
# 4  Cut Out Criss Cross One Piece Swimsuit  $9.50
#
#                                       brand  \
# 0  QingSang Accessories Apparel Accessories
# 1                                       NaN
# 2                                       NaN
# 3                                     ROMWE
# 4                                       NaN
#
#                                          description  \
# ...

# %%
shein['url'].is_unique
# Out:
# False

# %%
# Remove rows with null or 0.00 price and products with null titles
shein = shein[shein['price'].notnull() & (shein['price'] != 0.00) & (shein['name'].notnull())]
shein.head(50)
# Out:
#                                                   url  \
# 0   https://us.shein.com/Flower-Decor-Face-Coverin...
# 1   https://us.shein.com/Lace-Up-Bodycon-Skirt-p-7...
# 2   https://us.shein.com/High-Waist-Twist-Front-Sh...
# 3   https://us.shein.com/ROMWE-Sweetness-Cherry-La...
# 4   https://us.shein.com/Cut-Out-Criss-Cross-One-P...
# 5   https://us.shein.com/Tie-Backless-Halter-Trian...
# 6   https://us.shein.com/Solid-Tie-Side-Cover-Up-S...
# 7   https://us.shein.com/ROMWE-PUNK-Tie-Dye-Letter...
# 8   https://us.shein.com/O-ring-Detail-Halter-Knot...
# 9   https://us.shein.com/Bow-Bead-Decor-Face-Cover...
# 10  https://us.shein.com/SHEIN-ICON-Buckle-Tape-Cu...
# 11  https://us.shein.com/ROMWE-PUNK-Grunge-High-Wa...
# 12  https://us.shein.com/Paperbag-Waist-Wide-Leg-P...
# 13  https://us.shein.com/Contrast-Mesh-Cut-Out-Hal...
# 14  https://us.shein.com/Color-Block-Triangle-Thon...
# 15  https://us.shein.com/Split-Thigh-Cover-Up-p-29...
# ...

# %%
shein.to_csv('cleaned_data/shein_cleaned_data.csv', index=True)

# %%
temu_path = "/Users/COMPUTER/PycharmProjects/pythonProject2/datasets/temu_product_sales_dataset 2.csv"
temu = pd.read_csv(temu_path)
temu.head()
# Out:
#    leve_1_category_id  leve_1_category_name  leve_2_category_id  \
# 0                 885  Patio, Lawn & Garden                 888
# 1                 885  Patio, Lawn & Garden                 888
# 2                 885  Patio, Lawn & Garden                 888
# 3                 885  Patio, Lawn & Garden                 888
# 4                 885  Patio, Lawn & Garden                 888
#
#                  leve_2_category_name  \
# 0  Outdoor Supplies & Patio Furniture
# 1  Outdoor Supplies & Patio Furniture
# 2  Outdoor Supplies & Patio Furniture
# 3  Outdoor Supplies & Patio Furniture
# 4  Outdoor Supplies & Patio Furniture
#
#                                                title          goods_id  \
# 0  1pc 30 LED Bubble Ball Lights Solar String Lig...  6017592186061056
# 1  50 LED Solar Sakura Lights Outdoor Waterproof ...  6017592186060804
# 2  10m 20m 30m Solar Copper Wire String Light Hol...  6017592186060676
# ...

# %%
temu['goods_id'].is_unique
# Out:
# False

# %%
temu['title'].is_unique
# Out:
# False

# %%
temu = temu.drop(['comments_num_raw','price_str', "sales_info"], axis=1)
temu.head()
# Out:
#    leve_1_category_id  leve_1_category_name  leve_2_category_id  \
# 0                 885  Patio, Lawn & Garden                 888
# 1                 885  Patio, Lawn & Garden                 888
# 2                 885  Patio, Lawn & Garden                 888
# 3                 885  Patio, Lawn & Garden                 888
# 4                 885  Patio, Lawn & Garden                 888
#
#                  leve_2_category_name  \
# 0  Outdoor Supplies & Patio Furniture
# 1  Outdoor Supplies & Patio Furniture
# 2  Outdoor Supplies & Patio Furniture
# 3  Outdoor Supplies & Patio Furniture
# 4  Outdoor Supplies & Patio Furniture
#
#                                                title          goods_id  \
# 0  1pc 30 LED Bubble Ball Lights Solar String Lig...  6017592186061056
# 1  50 LED Solar Sakura Lights Outdoor Waterproof ...  6017592186060804
# 2  10m 20m 30m Solar Copper Wire String Light Hol...  6017592186060676
# ...

# %%
temu = temu.drop(["goods_id"], axis=1)
temu.head()
# Out:
#    leve_1_category_id  leve_1_category_name  leve_2_category_id  \
# 0                 885  Patio, Lawn & Garden                 888
# 1                 885  Patio, Lawn & Garden                 888
# 2                 885  Patio, Lawn & Garden                 888
# 3                 885  Patio, Lawn & Garden                 888
# 4                 885  Patio, Lawn & Garden                 888
#
#                  leve_2_category_name  \
# 0  Outdoor Supplies & Patio Furniture
# 1  Outdoor Supplies & Patio Furniture
# 2  Outdoor Supplies & Patio Furniture
# 3  Outdoor Supplies & Patio Furniture
# 4  Outdoor Supplies & Patio Furniture
#
#                                                title  category_id  visible  \
# 0  1pc 30 LED Bubble Ball Lights Solar String Lig...          891     True
# 1  50 LED Solar Sakura Lights Outdoor Waterproof ...          891     True
# 2  10m 20m 30m Solar Copper Wire String Light Hol...          891     True
# ...

# %%
# Remove rows with null or 0.00 price and products with null titles
temu = temu[temu['price'].notnull() & (temu['price'] != 0.00) & (temu['title'].notnull())]
temu.head(50)
# Out:
#     leve_1_category_id  leve_1_category_name  leve_2_category_id  \
# 0                  885  Patio, Lawn & Garden                 888
# 1                  885  Patio, Lawn & Garden                 888
# 2                  885  Patio, Lawn & Garden                 888
# 3                  885  Patio, Lawn & Garden                 888
# 4                  885  Patio, Lawn & Garden                 888
# 5                  885  Patio, Lawn & Garden                 888
# 6                  885  Patio, Lawn & Garden                 888
# 7                  885  Patio, Lawn & Garden                 888
# 8                  885  Patio, Lawn & Garden                 888
# 9                  885  Patio, Lawn & Garden                 888
# 10                 885  Patio, Lawn & Garden                 888
# 11                 885  Patio, Lawn & Garden                 888
# 12                 885  Patio, Lawn & Garden                 888
# ...

# %%
temu.to_csv('cleaned_data/temu_cleaned_data.csv', index=True)
